# %% [markdown]
# # Verkaufspreis = A*Zimmer + B*Gewinn + C

# %%
import pandas as pd

df = pd.read_csv("hotels.csv")

df.head()
# Out:
#      Gewinn  Preis in Mio  Quadratmeter    Stadt
# 0  119000.0         21.88        3938.0   Berlin
# 1  250000.0         27.95        3986.0  München
# 2  250000.0         16.09        2574.0     Köln
# 3  145000.0         27.58        4155.0  München
# 4  110000.0         23.76        3795.0   Berlin

# %%
x = df[["Quadratmeter", "Gewinn"]].values
y = df[["Preis in Mio"]].values
x
# Out:
# array([[3.938e+03, 1.190e+05],
#        [3.986e+03, 2.500e+05],
#        [2.574e+03, 2.500e+05],
#        [4.155e+03, 1.450e+05],
#        [3.795e+03, 1.100e+05],
#        [2.773e+03, 2.460e+05],
#        [6.340e+02, 5.400e+04],
#        [8.200e+01, 2.000e+03],
#        [3.706e+03, 1.140e+05],
#        [1.692e+03, 4.700e+04],
#        [1.989e+03, 5.400e+04],
#        [2.616e+03, 1.240e+05],
#        [3.358e+03, 1.250e+05],
#        [1.941e+03, 6.200e+04],
#        [1.831e+03, 2.500e+05],
#        [8.000e+02, 2.400e+04],
#        [2.700e+03, 1.020e+05],
#        [1.257e+03, 2.600e+04],
#        [2.644e+03, 8.500e+04],
#        [2.001e+03, 1.820e+05],
#        [1.581e+03, 7.400e+04],
#        [8.200e+01, 5.000e+03],
#        [2.412e+03, 1.340e+05],
#        [7.690e+02, 1.400e+04],
#        [3.815e+03, 8.400e+04],
#        [3.122e+03, 1.240e+05],
#        [1.492e+03, 3.200e+04],
#        [5.250e+02, 2.500e+05],
#        [1.217e+03, 5.300e+04],
#        [1.497e+03, 3.200e+04],
#        [3.101e+03, 6.300e+04],
#        [2.644e+03, 8.800e+04],
#        [3.631e+03, 1.560e+05],
#        [1.461e+03, 1.380e+05],
#        [1.492e+03, 3.700e+04],
#        [2.408e+03, 8.600e+04],
#        [8.590e+02, 1.700e+04],
#        [7.030e+02, 2.300e+04],
#        [4.908e+03, 1.360e+05],
#        [2.545e+03, 1.290e+05],
#        [1.847e+03, 3.400e+04],
#        [5.020e+02, 1.800e+04],
#        [3.478e+03, 1.370e+05],
#        [7.560e+02, 7.300e+04],
#        [5.099e+03, 1.560e+05],
#        [1.215e+03, 2.100e+04],
#        [3.107e+03, 9.100e+04],
#        [2.375e+03, 7.200e+04],
#        [2.101e+03, 1.010e+05],
#        [4.832e+03, 2.500e+05],
#        [2.458e+03, 5.700e+04],
#        [4.561e+03, 8.300e+04],
#        [4.044e+03, 8.700e+04],
#        [3.896e+03, 1.410e+05],
#        [2.630e+03, 9.900e+04],
#        [3.249e+03, 2.500e+05],
#        [2.409e+03, 9.900e+04],
#        [2.618e+03, 1.130e+05],
#        [3.366e+03, 8.300e+04],
#        [1.625e+03, 2.900e+04],
#        [3.149e+03, 6.800e+04],
#        [3.944e+03, 1.210e+05],
#        [3.162e+03, 7.100e+04],
#        [1.993e+03, 6.400e+04],
#        [2.583e+03, 2.500e+05],
#        [2.301e+03, 9.700e+04],
#        [1.710e+02, 4.000e+03],
#        [3.876e+03, 2.500e+05],
#        [3.040e+02, 1.300e+04],
#        [3.849e+03, 2.500e+05],
#        [2.795e+03, 6.600e+04],
#        [5.702e+03, 2.500e+05],
#        [4.082e+03, 7.500e+04],
#        [3.910e+03, 1.250e+05],
#        [4.565e+03, 1.260e+05],
#        [4.436e+03, 2.500e+05],
#        [1.355e+03, 2.500e+05],
#        [2.220e+03, 6.400e+04],
#        [3.674e+03, 9.700e+04],
#        [2.847e+03, 9.100e+04],
#        [5.201e+03, 1.240e+05],
#        [1.002e+03, 2.500e+04],
#        [3.306e+03, 5.800e+04],
#        [2.952e+03, 5.700e+04],
#        [7.230e+02, 1.900e+04],
#        [7.600e+02, 2.300e+04],
#        [1.241e+03, 2.600e+04],
#        [3.168e+03, 9.600e+04],
#        [5.741e+03, 2.500e+05],
#        [1.873e+03, 4.500e+04],
#        [1.140e+02, 3.000e+03],
#        [3.707e+03, 1.160e+05],
#        [3.165e+03, 8.000e+04],
#        [1.799e+03, 6.200e+04],
#        [6.470e+02, 8.500e+04],
#        [3.960e+02, 2.000e+04],
#        [1.346e+03, 6.100e+04],
#        [5.427e+03, 1.420e+05],
#        [3.085e+03, 1.560e+05],
#        [1.594e+03, 3.900e+04],
#        [3.619e+03, 1.630e+05],
#        [1.127e+03, 1.280e+05],
#        [2.985e+03, 7.100e+04],
#        [2.770e+03, 6.700e+04],
#        [2.420e+02, 7.000e+03],
#        [5.519e+03, 2.500e+05],
#        [3.062e+03, 6.900e+04],
#        [4.681e+03, 1.200e+05],
#        [2.501e+03, 3.400e+04],
#        [1.690e+03, 2.500e+04],
#        [4.494e+03, 8.900e+04],
#        [2.671e+03, 1.760e+05],
#        [5.549e+03, 2.500e+05],
#        [1.275e+03, 1.030e+05],
#        [2.218e+03, 5.600e+04],
#        [2.186e+03, 7.600e+04],
#        [3.800e+02, 7.000e+03],
#        [1.505e+03, 3.300e+04],
#        [4.151e+03, 1.210e+05],
#        [1.781e+03, 4.400e+04],
#        [5.607e+03, 2.500e+05],
#        [5.643e+03, 1.250e+05],
#        [3.309e+03, 1.250e+05],
#        [3.302e+03, 4.800e+04],
#        [3.429e+03, 9.500e+04],
#        [2.584e+03, 2.500e+05],
#        [3.224e+03, 1.350e+05],
#        [7.880e+02, 4.400e+04],
#        [3.708e+03, 1.920e+05],
#        [1.489e+03, 6.300e+04],
#        [2.244e+03, 8.700e+04],
#        [1.790e+02, 1.100e+04],
#        [2.220e+03, 1.210e+05],
#        [3.374e+03, 1.040e+05],
#        [1.696e+03, 2.270e+05],
#        [2.115e+03, 2.500e+05],
#        [3.558e+03, 2.500e+05],
#        [1.021e+03, 3.500e+04],
#        [4.008e+03, 1.870e+05],
#        [2.670e+02, 8.000e+03],
#        [5.256e+03, 2.500e+05],
#        [2.337e+03, 2.320e+05],
#        [4.490e+02, 8.000e+03],
#        [4.763e+03, 2.130e+05],
#        [3.078e+03, 1.590e+05],
#        [1.775e+03, 4.500e+04],
#        [4.058e+03, 2.500e+05],
#        [1.668e+03, 3.200e+04],
#        [2.281e+03, 3.500e+04],
#        [2.297e+03, 9.000e+04]])

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 0)


from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)

print(model.intercept_)
print(model.coef_)
# Out:
# [6.48370247]
# [[3.89642288e-03 6.39855984e-06]]

# %%
y_test_pred = model.predict(x_test)

for i in range(0,len(y_test_pred)):
    print(str(y_test_pred[i][0]) + " - " + str(y_test[i][0]))
# Out:
# 15.484287770456309 - 14.56
# 19.25848936697959 - 16.32
# 13.059377556544966 - 13.09
# 25.490685154062852 - 22.87
# 6.816006267056254 - 8.94
# 21.62782212809594 - 19.13
# 13.897946565496632 - 13.77
# 11.485525821358022 - 9.63
# 13.362995432755906 - 10.41
# 30.30074569339602 - 32.78
# 14.544508758730881 - 12.98
# 24.7863676945318 - 23.6
# 22.518535912530904 - 20.27
# 17.364752070043465 - 21.26
# 14.658781101070204 - 13.86
# 9.370054632254533 - 9.76
# 21.419820437400865 - 24.81
# 6.947090359060697 - 6.62
# 11.35222602729527 - 8.69
# 17.656697351169136 - 14.16
# 29.271036764081238 - 28.49
# 7.175585023072502 - 6.95
# 21.886034785667135 - 22.4
# 21.653281486765614 - 24.87
# 19.909575414999082 - 16.94
# 16.73928147636494 - 15.54
# 27.349738072086637 - 24.78
# 28.538184939132957 - 30.14
# 13.890077942623035 - 16.15
# 12.501919323322053 - 17.75
# 10.68589982620841 - 7.91
# 9.422388850520345 - 7.98
# 10.128964442111485 - 6.73
# 9.835620333614969 - 6.3
# 15.90798700549315 - 13.21
# 13.00094788689616 - 10.94
# 17.329722152677316 - 19.59
# 18.350660724427478 - 15.18
